# %%
import numpy as np
import pandas as pd
rng = np.random.default_rng()

# %% [markdown]
# # MAIN

# %%
class WareHouse:
    # noinspection JupyterPackage
    """
    Raktár
    """

    EXPIRATION = 7
    EXPIRATION_TRASH = 3

    ITEM_ORDER_DELAY = 4

    def __init__(self, days, supplied_stores=None, start_quantity=0):
        if supplied_stores is None:
            supplied_stores = []

        self.supplied_stores = supplied_stores

        self.storage = WareHouse.create_items(start_quantity)

        self.incoming : list[pd.DataFrame] = [
            WareHouse.create_items(0) for _ in range(days)
        ]

    def update_storage(self, day_index):
        """
        Áruk megérkeznek a boltba
        """
        self.storage = pd.concat((self.storage, self.incoming[day_index]))

    def update_predictions(self, day_index, prediction_amount):
        """
        Előrejelzések módosítása
        """
        self.incoming[day_index+WareHouse.ITEM_ORDER_DELAY] = WareHouse.create_items(prediction_amount)

    def drop_expired(self):
        """
        Kidobjuk a WH_EXP_TRASH-nál kisebb értékű termékeket
        :return: kidobott termékek száma
        """

        nr_of_dropped_ = self.storage[self.storage['expiration']<WareHouse.EXPIRATION_TRASH].shape[0]

        self.storage = self.storage[self.storage['expiration']>=WareHouse.EXPIRATION_TRASH]

        return nr_of_dropped_

    def supply(self, amount):
        """
        Termékek leszállítása
        :param amount: mennyiség
        :return: leszállított termékek
        """
        supplied = self.storage.sort_values('expiration', ascending=True).head(amount)
        self.storage.drop(supplied.index, inplace=True)
        return supplied

    # noinspection PyPep8Naming
    @property
    def storageSize(self):
        """
        :return: Raktár készlet nagysága
        """
        return self.storage.shape[0]

    @staticmethod
    def create_items(amount):
        return pd.DataFrame(
            {'expiration': [WareHouse.EXPIRATION]*amount}
        )


class Store:
    """
    Bolt
    """

    EXPIRATION_START = 1
    EXPIRATION_END = 5

    def __init__(self, days, start_quantity=0):
        self.predictions = [{'center' : rng.uniform(80,120), 'scale' : rng.uniform(10,30)} for _ in range(days)]
        self.storage = pd.DataFrame(
            {'expiration':
                [rng.uniform(Store.EXPIRATION_START, Store.EXPIRATION_END) for _ in range(start_quantity)]
            })

    def get_order(self, day_index):
        return round(self.predictions[day_index]['center'])

    def get_demand(self, day_index):
        prediction = self.predictions[day_index]
        demand = rng.normal(prediction['center'], prediction['scale'])
        while demand < 0:
            demand = rng.normal(demand)

        return round(demand)

    def sell(self, amount):
        if amount > self.storageSize: raise ValueError("Nincs ennyi termék a boltban")


        for i in range(amount):
            current_sale = self.get_random_expiration()
            while current_sale not in list(self.storage.expiration):
                current_sale = self.get_random_expiration()

            pos = self.storage[self.storage['expiration'] == current_sale].index[0]

            self.storage.drop(pos, inplace=True)


    def drop_expired(self):
        """
        Kidobjuk a lejárt termékeket
        :return: kidobott termékek száma
        """

        nr_of_dropped_ = self.storage[self.storage['expiration']<1].shape[0]
        self.storage = self.storage[self.storage['expiration']>=1]

        return nr_of_dropped_

    # noinspection PyPep8Naming
    @property
    def storageSize(self):
        """
        :return: Bolt készletének nagysága
        """
        return self.storage.shape[0]

    def get_random_expiration(self):
        """adott min es max lejarattal generalunk vasarloi eloszlast
        ez itt: sokan vesznek hamar lejarot (akciok miatt)
        sokan vesznek friss termeket
        ket random eloszlas osszeget vesszuk"""

        assert self.storageSize > 0
        f1 = min(self.storage['expiration'])
        f2 = max(self.storage['expiration'])
        customer_demand_dist = list(filter(lambda x: (f1 <= x <= f2), list(np.random.normal(f1, (f2 - f1) * 0.1, 50)) + list(np.random.normal(f2, (f2 - f1) // 3, 100))))
        return round(np.random.choice(customer_demand_dist))

# %%
def run_simulation(days, nr_stores):
    stores = [Store(days) for _ in range(nr_stores)]
    warehouse = WareHouse(days, stores, 1000)

    for current_day in range(days):
        print('-'*50+f" {current_day+1}. NAP "+"-"*50)

        warehouse.update_storage(current_day)


        if current_day + WareHouse.ITEM_ORDER_DELAY < days:
            # RAKTÁRi RENDELÉS
            storage_order = 0
            for store in stores:
                storage_order += round(store.predictions[current_day+WareHouse.ITEM_ORDER_DELAY]['center'])

            warehouse.update_predictions(current_day, storage_order)
            print(f"Rendel a raktár: {storage_order}-t a {current_day+WareHouse.ITEM_ORDER_DELAY+1}. napra.")


        # BOLTI KISZÁLLÍTÁS ÖSSZEGZÉS
        store_order = 0
        for store in stores:
            store_order += round(store.predictions[current_day]['center'])

        if store_order > warehouse.storageSize:
            print('Raktár nem tudja teljesíteni a rendelést!')
            print(f"COST (Raktár kiszállítás nem teljes): {store_order-warehouse.storageSize}")


        # BOLTI KISZÁLLÍTÁS, ELADÁS
        for (i, store) in enumerate(stores, start=1):
            print(f"{'-'*10} {i}. Bolt {'-'*10}")

            # BOLTI KISZÁLLÍTÁS
            current_order = store.get_order(current_day)
            print(f"Ennyit rendel a bolt mara: {current_order}")

            if current_order > warehouse.storageSize:
                print("A raktár erre a boltra nem tudja teljesíteni a kiszállítást!")
                c_order = warehouse.storageSize
                print(f'A raktár csak ennyit szállít ki: {c_order}')
                print(f"COST: {current_order-warehouse.storageSize}")


            store.storage = pd.concat((store.storage, warehouse.supply(current_order)))
            store.storage.reset_index(inplace=True, drop=True)


            # BOLTI ELADÁS
            current_demand = store.get_demand(current_day)


            print(f"Bolti keszlet: {store.storageSize}")
            print(f"Ennyit akarnak venni: {current_demand}")


            if current_demand > store.storageSize:
                print("A boltban nincs elég termék")
                print(f"COST: {current_demand-store.storageSize}")
            current_sale = min(store.storageSize, current_demand)

            store.sell(current_sale)
            print(f"Ennyi terméket adtak el: {current_sale}")


            # BOLTI LEJÁRT TERMÉKEK KIDOBÁSA
            store.storage['expiration'] -= 1
            nr_of_dropped = store.drop_expired()

            print(f"HIBA (bolti kidobás): {nr_of_dropped}")

            print(f"Bolti keszlet: {store.storageSize}")


        # RAKTÁRI LEJÁRT TERMÉKEK KIDOBÁSA
        print('-'*25)
        warehouse.storage['expiration'] -= 1
        nr_of_dropped = warehouse.drop_expired()

        print(f"HIBA (raktari kidobás): {nr_of_dropped}")
        print(f"Raktár készlet: {warehouse.storageSize}")

# %%
run_simulation(
    days = 10,
    nr_stores = 3
)
# Out:
# -------------------------------------------------- 1. NAP --------------------------------------------------
# Rendel a raktár: 291-t a 5. napra.
# ---------- 1. Bolt ----------
# Ennyit rendel a bolt mara: 115
# Bolti keszlet: 115
# Ennyit akarnak venni: 137
# A boltban nincs elég termék
# COST: 22
# Ennyi terméket adtak el:115
# HIBA (bolti kidobás): 0
# Bolti keszlet: 0
# ---------- 2. Bolt ----------
# Ennyit rendel a bolt mara: 97
# Bolti keszlet: 97
# Ennyit akarnak venni: 51
# Ennyi terméket adtak el:51
# HIBA (bolti kidobás): 0
# Bolti keszlet: 46
# ---------- 3. Bolt ----------
# Ennyit rendel a bolt mara: 109
# Bolti keszlet: 109
# Ennyit akarnak venni: 120
# A boltban nincs elég termék
# COST: 11
# Ennyi terméket adtak el:109
# HIBA (bolti kidobás): 0
# Bolti keszlet: 0
# -------------------------
# HIBA (raktari kidobás): 0
# Raktár készlet: 679
# -------------------------------------------------- 2. NAP --------------------------------------------------
# Rendel a raktár: 300-t a 6. napra.
# ---------- 1. Bolt ----------
# Ennyit rendel a bolt mara: 115
# Bolti keszlet: 115
# Ennyit akarnak venni: 125
# A boltban nincs elég termék
# COST: 10
# Ennyi terméket adtak el:115
# HIBA (bolti kidobás): 0
# Bolti keszlet: 0
# ---------- 2. Bolt ----------
# Ennyit rendel a bolt mara: 103
# Bolti keszlet: 149
# Ennyit akarnak venni: 119
# Ennyi terméket adtak el:119
# HIBA (bolti kidobás): 0
# Bolti keszlet: 30
# ---------- 3. Bolt ----------
# Ennyit rendel a bolt mara: 104
# Bolti keszlet: 104
# Ennyit akarnak venni: 82
# Ennyi terméket adtak el:82
# HIBA (bolti kidobás): 0
# Bolti keszlet: 22
# -------------------------
# HIBA (raktari kidobás): 0
# Raktár készlet: 357
# -------------------------------------------------- 3. NAP --------------------------------------------------
# Rendel a raktár: 319-t a 7. napra.
# ---------- 1. Bolt ----------
# Ennyit rendel a bolt mara: 105
# Bolti keszlet: 105
# Ennyit akarnak venni: 127
# A boltban nincs elég termék
# COST: 22
# Ennyi terméket adtak el:105
# HIBA (bolti kidobás): 0
# Bolti keszlet: 0
# ---------- 2. Bolt ----------
# Ennyit rendel a bolt mara: 84
# Bolti keszlet: 114
# Ennyit akarnak venni: 99
# Ennyi terméket adtak el:99
# HIBA (bolti kidobás): 0
# Bolti keszlet: 15
# ---------- 3. Bolt ----------
# Ennyit rendel a bolt mara: 91
# Bolti keszlet: 113
# Ennyit akarnak venni: 115
# A boltban nincs elég termék
# COST: 2
# Ennyi terméket adtak el:113
# HIBA (bolti kidobás): 0
# Bolti keszlet: 0
# -------------------------
# HIBA (raktari kidobás): 0
# Raktár készlet: 77
# -------------------------------------------------- 4. NAP --------------------------------------------------
# Rendel a raktár: 297-t a 8. napra.
# Raktár nem tudja teljesíteni a rendelést!
# COST (Raktár kiszállítás nem teljes): 239
# ---------- 1. Bolt ----------
# Ennyit rendel a bolt mara: 117
# A raktár erre a boltra nem tudja teljesíteni a kiszállítást!
# A raktár csak ennyit szállít ki: 77
# COST: 40
# Bolti keszlet: 77
# Ennyit akarnak venni: 110
# A boltban nincs elég termék
# COST: 33
# Ennyi terméket adtak el:77
# HIBA (bolti kidobás): 0
# Bolti keszlet: 0
# ---------- 2. Bolt ----------
# Ennyit rendel a bolt mara: 109
# A raktár erre a boltra nem tudja teljesíteni a kiszállítást!
# A raktár csak ennyit szállít ki: 0
# COST: 109
# Bolti keszlet: 15
# Ennyit akarnak venni: 107
# A boltban nincs elég termék
# COST: 92
# Ennyi terméket adtak el:15
# HIBA (bolti kidobás): 0
# Bolti keszlet: 0
# ---------- 3. Bolt ----------
# Ennyit rendel a bolt mara: 90
# A raktár erre a boltra nem tudja teljesíteni a kiszállítást!
# A raktár csak ennyit szállít ki: 0
# COST: 90
# Bolti keszlet: 0
# Ennyit akarnak venni: 66
# A boltban nincs elég termék
# COST: 66
# Ennyi terméket adtak el:0
# HIBA (bolti kidobás): 0
# Bolti keszlet: 0
# -------------------------
# HIBA (raktari kidobás): 0
# Raktár készlet: 0
# -------------------------------------------------- 5. NAP --------------------------------------------------
# Rendel a raktár: 319-t a 9. napra.
# ---------- 1. Bolt ----------
# Ennyit rendel a bolt mara: