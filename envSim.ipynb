# %%
import numpy as np
import pandas as pd
from collections import Counter
rng = np.random.default_rng()

# %% [markdown]
# # MAIN

# %%
class WareHouse:
    # noinspection JupyterPackage
    """
    Raktár
    """

    EXPIRATION = 7
    EXPIRATION_TRASH = 3

    ITEM_ORDER_DELAY = 4

    def __init__(self, days, supplied_stores=None, start_quantity=0):
        if supplied_stores is None:
            supplied_stores = []

        self.supplied_stores = supplied_stores

        self.storage = WareHouse.create_items(start_quantity)

        self.incoming : list[pd.DataFrame] = [
            WareHouse.create_items(0) for _ in range(days)
        ]

    def update_storage(self, day_index):
        """
        Áruk megérkeznek a boltba
        """
        self.storage = pd.concat((self.storage, self.incoming[day_index]))

    def update_predictions(self, day_index, prediction_amount):
        """
        Előrejelzések módosítása
        """
        self.incoming[day_index+WareHouse.ITEM_ORDER_DELAY] = WareHouse.create_items(prediction_amount)

    def drop_expired(self):
        """
        Kidobjuk a WH_EXP_TRASH-nál kisebb értékű termékeket
        :return: kidobott termékek száma
        """

        nr_of_dropped_ = self.storage[self.storage['expiration']<WareHouse.EXPIRATION_TRASH].shape[0]

        self.storage = self.storage[self.storage['expiration']>=WareHouse.EXPIRATION_TRASH]

        return nr_of_dropped_

    def supply(self, amount):
        """
        Termékek leszállítása
        :param amount: mennyiség
        :return: leszállított termékek
        """
        supplied = self.storage.sort_values('expiration', ascending=True).head(amount)
        self.storage.drop(supplied.index, inplace=True)
        return supplied

    # noinspection PyPep8Naming
    @property
    def storageSize(self):
        """
        :return: Raktár készlet nagysága
        """
        return self.storage.shape[0]

    @staticmethod
    def create_items(amount):
        return pd.DataFrame(
            {'expiration': [WareHouse.EXPIRATION]*amount}
        )


class Store:
    """
    Bolt
    """

    EXPIRATION_START = 1
    EXPIRATION_END = 5

    def __init__(self, days, start_quantity=0):
        self.predictions = [{'center' : rng.uniform(80,120), 'scale' : rng.uniform(10,30)} for _ in range(days)]
        self.storage = pd.DataFrame(
            {'expiration':
                [rng.uniform(Store.EXPIRATION_START, Store.EXPIRATION_END) for _ in range(start_quantity)]
            })

    def get_order(self, day_index):
        return round(self.predictions[day_index]['center'])

    def get_demand(self, day_index):
        prediction = self.predictions[day_index]
        demand = rng.normal(prediction['center'], prediction['scale'])
        while demand < 0:
            demand = rng.normal(demand)

        return round(demand)

    def sell(self, amount):
        if amount > self.storageSize: raise ValueError("Nincs ennyi termék a boltban")


        for i in range(amount):
            current_sale = self.get_random_expiration()
            while current_sale not in list(self.storage.expiration):
                current_sale = self.get_random_expiration()

            pos = self.storage[self.storage['expiration'] == current_sale].index[0]

            self.storage.drop(pos, inplace=True)


    def drop_expired(self):
        """
        Kidobjuk a lejárt termékeket
        :return: kidobott termékek száma
        """

        nr_of_dropped_ = self.storage[self.storage['expiration']<1].shape[0]
        self.storage = self.storage[self.storage['expiration']>=1]

        return nr_of_dropped_

    # noinspection PyPep8Naming
    @property
    def storageSize(self):
        """
        :return: Bolt készletének nagysága
        """
        return self.storage.shape[0]

    def get_random_expiration(self):
        """adott min es max lejarattal generalunk vasarloi eloszlast
        ez itt: sokan vesznek hamar lejarot (akciok miatt)
        sokan vesznek friss termeket
        ket random eloszlas osszeget vesszuk"""

        assert self.storageSize > 0
        f1 = min(self.storage['expiration'])
        f2 = max(self.storage['expiration'])
        customer_demand_dist = list(filter(lambda x: (f1 <= x <= f2), list(np.random.normal(f1, (f2 - f1) * 0.1, 50)) + list(np.random.normal(f2, (f2 - f1) // 3, 100))))
        return round(np.random.choice(customer_demand_dist))

# %%
def run_simulation(days, nr_stores, cost_weights):
    cost = Counter()

    stores = [Store(days) for _ in range(nr_stores)]
    warehouse = WareHouse(days, stores, 1000)

    for current_day in range(days):
        print('-'*50+f" {current_day+1}. NAP "+"-"*50)

        warehouse.update_storage(current_day)


        if current_day + WareHouse.ITEM_ORDER_DELAY < days:
            # RAKTÁRi RENDELÉS
            storage_order = 0
            for store in stores:
                storage_order += round(store.predictions[current_day+WareHouse.ITEM_ORDER_DELAY]['center'])

            warehouse.update_predictions(current_day, storage_order)
            print(f"Rendel a raktár: {storage_order}-t a {current_day+WareHouse.ITEM_ORDER_DELAY+1}. napra.")



        # BOLTI KISZÁLLÍTÁS, ELADÁS
        for (i, store) in enumerate(stores, start=1):
            print(f"{'-'*10} {i}. Bolt {'-'*10}")

            # BOLTI KISZÁLLÍTÁS
            current_order = store.get_order(current_day)
            final_order = current_order
            print(f"Ennyit rendel a bolt mara: {current_order}")

            if current_order > warehouse.storageSize:
                print("A raktár erre a boltra nem tudja teljesíteni a kiszállítást!")
                final_order = warehouse.storageSize
                print(f'A raktár csak ennyit szállít ki: {final_order}')
                print(f"COST: {current_order-final_order}")

                cost['not_enough_in_warehouse'] += (current_order-final_order)*cost_weights['not_enough_in_warehouse']



            store.storage = pd.concat((store.storage, warehouse.supply(final_order)))
            store.storage.reset_index(inplace=True, drop=True)


            # BOLTI ELADÁS
            demand = store.get_demand(current_day)

            print(f"Bolti keszlet: {store.storageSize}")
            print(f"Ennyit akarnak venni: {demand}")


            if demand > store.storageSize:
                print("A boltban nincs elég termék")
                print(f"COST: {demand-store.storageSize}")
                cost['not_enough_in_store'] = (demand-store.storageSize)*cost_weights['not_enough_in_store']

            current_sale = min(store.storageSize, demand)

            store.sell(current_sale)
            print(f"Ennyi terméket adtak el: {current_sale}")


            # BOLTI LEJÁRT TERMÉKEK KIDOBÁSA
            store.storage['expiration'] -= 1
            nr_of_dropped = store.drop_expired()

            print(f"HIBA (bolti kidobás): {nr_of_dropped}")
            cost['store_throwout'] = nr_of_dropped * cost_weights['store_throwout']

            print(f"Bolti keszlet: {store.storageSize}")


        # RAKTÁRI LEJÁRT TERMÉKEK KIDOBÁSA
        print('-'*25)
        warehouse.storage['expiration'] -= 1
        nr_of_dropped = warehouse.drop_expired()

        print(f"HIBA (raktari kidobás): {nr_of_dropped}")
        cost['warehouse_throwout'] = nr_of_dropped * cost_weights['warehouse_throwout']
        print(f"Raktár készlet: {warehouse.storageSize}")

        print(cost)

    return cost

# %%
run_simulation(
    days = 10,
    nr_stores = 3,
    cost_weights = {
        'not_enough_in_store' : 1,
        'not_enough_in_warehouse' : 1,
        'store_throwout' : 5,
        'warehouse_throwout': 3

    }
)
# Out:
# -------------------------------------------------- 1. NAP --------------------------------------------------
# Rendel a raktár: 301-t a 5. napra.
# ---------- 1. Bolt ----------
# Ennyit rendel a bolt mara: 94
# Bolti keszlet: 94
# Ennyit akarnak venni: 101
# A boltban nincs elég termék
# COST: 7
# Ennyi terméket adtak el: 94
# HIBA (bolti kidobás): 0
# Bolti keszlet: 0
# ---------- 2. Bolt ----------
# Ennyit rendel a bolt mara: 92
# Bolti keszlet: 92
# Ennyit akarnak venni: 75
# Ennyi terméket adtak el: 75
# HIBA (bolti kidobás): 0
# Bolti keszlet: 17
# ---------- 3. Bolt ----------
# Ennyit rendel a bolt mara: 103
# Bolti keszlet: 103
# Ennyit akarnak venni: 100
# Ennyi terméket adtak el: 100
# HIBA (bolti kidobás): 0
# Bolti keszlet: 3
# -------------------------
# HIBA (raktari kidobás): 0
# Raktár készlet: 711
# Counter({'not_enough_in_store': 7, 'store_throwout': 0, 'warehouse_throwout': 0})
# -------------------------------------------------- 2. NAP --------------------------------------------------
# Rendel a raktár: 341-t a 6. napra.
# ---------- 1. Bolt ----------
# Ennyit rendel a bolt mara: 103
# Bolti keszlet: 103
# Ennyit akarnak venni: 58
# Ennyi terméket adtak el: 58
# HIBA (bolti kidobás): 0
# Bolti keszlet: 45
# ---------- 2. Bolt ----------
# Ennyit rendel a bolt mara: 119
# Bolti keszlet: 136
# Ennyit akarnak venni: 113
# Ennyi terméket adtak el: 113
# HIBA (bolti kidobás): 0
# Bolti keszlet: 23
# ---------- 3. Bolt ----------
# Ennyit rendel a bolt mara: 107
# Bolti keszlet: 110
# Ennyit akarnak venni: 102
# Ennyi terméket adtak el: 102
# HIBA (bolti kidobás): 0
# Bolti keszlet: 8
# -------------------------
# HIBA (raktari kidobás): 0
# Raktár készlet: 382
# Counter({'not_enough_in_store': 7, 'store_throwout': 0, 'warehouse_throwout': 0})
# -------------------------------------------------- 3. NAP --------------------------------------------------
# Rendel a raktár: 298-t a 7. napra.
# ---------- 1. Bolt ----------
# Ennyit rendel a bolt mara: 111
# Bolti keszlet: 156
# Ennyit akarnak venni: 118
# Ennyi terméket adtak el: 118
# HIBA (bolti kidobás): 0
# Bolti keszlet: 38
# ---------- 2. Bolt ----------
# Ennyit rendel a bolt mara: 103
# Bolti keszlet: 126
# Ennyit akarnak venni: 103
# Ennyi terméket adtak el: 103
# HIBA (bolti kidobás): 0
# Bolti keszlet: 23
# ---------- 3. Bolt ----------
# Ennyit rendel a bolt mara: 93
# Bolti keszlet: 101
# Ennyit akarnak venni: 92
# Ennyi terméket adtak el: 92
# HIBA (bolti kidobás): 0
# Bolti keszlet: 9
# -------------------------
# HIBA (raktari kidobás): 0
# Raktár készlet: 75
# Counter({'not_enough_in_store': 7, 'store_throwout': 0, 'warehouse_throwout': 0})
# -------------------------------------------------- 4. NAP --------------------------------------------------
# Rendel a raktár: 309-t a 8. napra.
# ---------- 1. Bolt ----------
# Ennyit rendel a bolt mara: 102
# A raktár erre a boltra nem tudja teljesíteni a kiszállítást!
# A raktár csak ennyit szállít ki: 75
# COST: 27
# Bolti keszlet: 113
# Ennyit akarnak venni: 153
# A boltban nincs elég termék
# COST: 40
# Ennyi terméket adtak el: 113
# HIBA (bolti kidobás): 0
# Bolti keszlet: 0
# ---------- 2. Bolt ----------
# Ennyit rendel a bolt mara: 114
# A raktár erre a boltra nem tudja teljesíteni a kiszállítást!
# A raktár csak ennyit szállít ki: 0
# COST: 114
# Bolti keszlet: 23
# Ennyit akarnak venni: 85
# A boltban nincs elég termék
# COST: 62
# Ennyi terméket adtak el: 23
# HIBA (bolti kidobás): 0
# Bolti keszlet: 0
# ---------- 3. Bolt ----------
# Ennyit rendel a bolt mara: 97
# A raktár erre a boltra nem tudja teljesíteni a kiszállítást!
# A raktár csak ennyit szállít ki: 0
# COST: 97
# Bolti keszlet: 9
# Ennyit akarnak venni: 114
# A boltban nincs elég termék
# COST: 105
# Ennyi terméket adtak el: 9
# HIBA (bolti kidobás): 0
# Bolti keszlet: 0
# -------------------------
# HIBA (raktari kidobás): 0
# Raktár készlet: 0
# Counter({'not_enough_in_warehouse': 238, 'not_enough_in_store': 105, 'store_throwout': 0, 'warehouse_throwout': 0})
# -------------------------------------------------- 5. NAP --------------------------------------------------
# Rendel a raktár: 302-t a 9. napra.
# ---------- 1. Bolt ----------
# Ennyit rendel a bolt mara: 90
# Bolti keszlet: 90
# Ennyit akarnak venni: 75
# Ennyi terméket adtak el: 75
# HIBA (bolti kidobás): 0
# Bolti keszlet: 15
# ---------- 2. Bolt ----------
# Ennyit rendel a bolt mara: 98
# Bolti keszlet: 98
# Ennyit akarnak venni: 82
# Ennyi terméket adtak el: 82
# HIBA (bolti kidobás): 0
# Bolti keszlet: 16
# ---------- 3. Bolt ----------
# Ennyit rendel a bolt mara: 113
# Bolti keszlet: 113
# Ennyit akarnak venni: 118
# A boltban nincs elég termék
# COST: 5
# Ennyi terméket adtak el: 113
# HIBA (bolti kidobás): 0
# Bolti keszlet: 0
# -------------------------
# HIBA (raktari kidobás): 0
# Raktár készlet: 0
# Counter({'not_enough_in_warehouse': 238, 'not_enough_in_store': 5, 'store_throwout': 0, 'warehouse_throwout': 0})
# -------------------------------------------------- 6. NAP --------------------------------------------------
# Rendel a raktár: 295-t a 10. napra.
# ---------- 1. Bolt ----------
# Ennyit rendel a bolt mara: 110
# Bolti keszlet: 125
# Ennyit akarnak venni: 97
# Ennyi terméket adtak el: 97
# HIBA (bolti kidobás): 0
# Bolti keszlet: 28
# ---------- 2. Bolt ----------
# Ennyit rendel a bolt mara: 118
# Bolti keszlet: 134
# Ennyit akarnak venni: 127
# Ennyi terméket adtak el: 127
# HIBA (bolti kidobás): 0
# Bolti keszlet: 7
# ---------- 3. Bolt ----------
# Ennyit rendel a bolt mara: 113
# Bolti keszlet: 113
# Ennyit akarnak venni: 141
# A boltban nincs elég termék
# COST: 28
# Ennyi terméket adtak el: 113
# HIBA (bolti kidobás): 0
# Bolti keszlet: 0
# -------------------------
# HIBA (raktari kidobás): 0
# Raktár készlet: 0
# Counter({'not_enough_in_warehouse': 238, 'not_enough_in_store': 28, 'store_throwout': 0, 'warehouse_throwout': 0})
# -------------------------------------------------- 7. NAP --------------------------------------------------
# ---------- 1. Bolt ----------
# Ennyit rendel a bolt mara: 86
# Bolti keszlet: 114
# Ennyit akarnak venni: 107
# Ennyi terméket adtak el: 107
# HIBA (bolti kidobás): 0
# Bolti keszlet: 7
# ---------- 2. Bolt ----------
# Ennyit rendel a bolt mara: 119
# Bolti keszlet: 126
# Ennyit akarnak venni: 109
# Ennyi terméket adtak el: 109
# HIBA (bolti kidobás): 0
# Bolti keszlet: 17
# ---------- 3. Bolt ----------
# Ennyit rendel a bolt mara: 93
# Bolti keszlet: 93
# Ennyit akarnak venni: 80
# Ennyi terméket adtak el: 80
# HIBA (bolti kidobás): 0
# Bolti keszlet: 13
# -------------------------
# HIBA (raktari kidobás): 0
# Raktár készlet: 0
# Counter({'not_enough_in_warehouse': 238, 'not_enough_in_store': 28, 'store_throwout': 0, 'warehouse_throwout': 0})
# -------------------------------------------------- 8. NAP --------------------------------------------------
# ---------- 1. Bolt ----------
# Ennyit rendel a bolt mara: 113
# Bolti keszlet: 120
# Ennyit akarnak venni: 113
# Ennyi terméket adtak el: 113
# HIBA (bolti kidobás): 0
# Bolti keszlet: 7
# ---------- 2. Bolt ----------
# Ennyit rendel a bolt mara: 111
# Bolti keszlet: 128
# Ennyit akarnak venni: 108
# Ennyi terméket adtak el: 108
# HIBA (bolti kidobás): 0
# Bolti keszlet: 20
# ---------- 3. Bolt ----------
# Ennyit rendel a bolt mara: 85
# Bolti keszlet: 98
# Ennyit akarnak venni: 48
# Ennyi terméket adtak el: 48
# HIBA (bolti kidobás): 0
# Bolti keszlet: 50
# -------------------------
# HIBA (raktari kidobás): 0
# Raktár készlet: 0
# Counter({'not_enough_in_warehouse': 238, 'not_enough_in_store': 28, 'store_throwout': 0, 'warehouse_throwout': 0})
# -------------------------------------------------- 9. NAP --------------------------------------------------
# ---------- 1. Bolt ----------
# Ennyit rendel a bolt mara: 91
# Bolti keszlet: 98
# Ennyit akarnak venni: 78
# Ennyi terméket adtak el: 78
# HIBA (bolti kidobás): 0
# Bolti keszlet: 20
# ---------- 2. Bolt ----------
# Ennyit rendel a bolt mara: 97
# Bolti keszlet: 117
# Ennyit akarnak venni: 106
# Ennyi terméket adtak el: 106
# HIBA (bolti kidobás): 0
# Bolti keszlet: 11
# ---------- 3. Bolt ----------
# Ennyit rendel a bolt mara: 114
# Bolti keszlet: 164
# Ennyit akarnak venni: 112
# Ennyi terméket adtak el: 112
# HIBA (bolti kidobás): 0
# Bolti keszlet: 52
# -------------------------
# HIBA (raktari kidobás): 0
# Raktár készlet: 0
# Counter({'not_enough_in_warehouse': 238, 'not_enough_in_store': 28, 'store_throwout': 0, 'warehouse_throwout': 0})
# -------------------------------------------------- 10. NAP --------------------------------------------------
# ---------- 1. Bolt ----------
# Ennyit rendel a bolt mara: 94
# Bolti keszlet: 114
# Ennyit akarnak venni: 98
# Ennyi terméket adtak el: 98
# HIBA (bolti kidobás): 0
# Bolti keszlet: 16
# ---------- 2. Bolt ----------
# Ennyit rendel a bolt mara: 111
# Bolti keszlet: 122
# Ennyit akarnak venni: 114
# Ennyi terméket adtak el: 114
# HIBA (bolti kidobás): 0
# Bolti keszlet: 8
# ---------- 3. Bolt ----------
# Ennyit rendel a bolt mara: 90
# Bolti keszlet: 142
# Ennyit akarnak venni: 99
# Ennyi terméket adtak el: 99
# HIBA (bolti kidobás): 0
# Bolti keszlet: 43
# -------------------------
# HIBA (raktari kidobás): 0
# Raktár készlet: 0
# Counter({'not_enough_in_warehouse': 238, 'not_enough_in_store': 28, 'store_throwout': 0, 'warehouse_throwout': 0})
# Counter({'not_enough_in_store': 28,
#          'store_throwout': 0,
#          'warehouse_throwout': 0,
#          'not_enough_in_warehouse': 238})
